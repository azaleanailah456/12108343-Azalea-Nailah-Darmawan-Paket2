# %% [markdown]
# <a href="https://colab.research.google.com/github/azaleanailah456/12108343-Azalea-Nailah-Darmawan-Paket2/blob/master/Matkul_Pyhton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ('Halo') #Perkenalan coding

# Perintah perhitungan
print (12 + 9)
print (12 * 10)
print (12 - 2)
print (12 / 2)

# Buat contoh tabel
print ('==== Label Paket ====')
print ('pengiriman: Gudang cipinang')
print ('penerima: toko maju jaya')
print ('alamat: janaka 3 no.11')
print ('isi: 5 dus air mineral')


import pandas as pd

data = {
    'Pengiriman' : ['Gudang Cipinang'],
    'Penerima' : ['Toko maju jaya'],
    'Alamat' : ['Janaka 3 No.11'],
    'Isi' : ['5 Dus air mineral']
}

df = pd.DataFrame(data)
print(df)
# Out:
# Halo
# 21
# 120
# 10
# 6.0
# ==== Label Paket ====
# pengiriman: Gudang cipinang
# penerima: toko maju jaya
# alamat: janaka 3 no.11
# isi: 5 dus air mineral
#         Pengiriman        Penerima          Alamat                Isi
# 0  Gudang Cipinang  Toko maju jaya  Janaka 3 No.11  5 Dus air mineral

# %%
print ("=" * 30) #mengulang tanda sama dengan sebanyak 30 kali
print ("Total harga isi:", 5 * 45000)
print ("=" * 30)
# Out:
# ...
# Total harga isi: 225000
# ...

# %%
nama_barang = "Nasi Goreng"
qty = 10
harga = 22000
print(nama_barang)
print("Jumlah:", qty)
print("Total:", harga)
# Out:
# Nasi Goreng
# Jumlah: 10
# Total: 22000

# %%
asal_kampus = "Itl Trisakti"
print(asal_kampus)
# Out:
# Itl Trisakti

# %%
meja = 5

# %%
# Colab mengikuti urutan sel yag DIJALANKAN, bukan urutan tampilannya.
# solusi run cel yg pertama, lalu cel kedua panggil variable nya
print(meja)
# Out:
# 5

# %%
nama_barang = "sepatu"
stok = 10
harga1 = 30000

# %%
print(nama_barang, stok, harga1)
# Out:
# sepatu 10 30000

# %%
stok = 40
stok = stok - 15
stok = stok + 10
print(stok)
# Out:
# 35

# %%
print(type(5))
print(type(12.5))
print(type("5"))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
print(12 + 1)

# Pada teks, + berarti menggabung, bukan menjumlah
print("12" + "1")

print ('-' * 30)
# Konversi tipe
int("12") # teks -> Bilangan bulat
float("12.5") # teks -> Bilangan desimal
str(12) # angka -> teks
# Out:
# 13
# 121
# ------------------------------
# '12'
